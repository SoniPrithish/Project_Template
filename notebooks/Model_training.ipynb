# %%
import pandas as pd

# %%
df=pd.read_csv("./data/finalTrain.csv")

# %%
df.head()
# Out:
#    Unnamed: 0      ID Delivery_person_ID  Delivery_person_Age
# 0           0  0xcdcd      DEHRES17DEL01                 36.0  \
# 1           1  0xd987      KOCRES16DEL01                 21.0
# 2           2  0x2784     PUNERES13DEL03                 23.0
# 3           3  0xc8b6     LUDHRES15DEL02                 34.0
# 4           4  0xdb64      KNPRES14DEL02                 24.0
#
#    Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude
# 0                      4.2            30.327968             78.046106  \
# 1                      4.7            10.003064             76.307589
# 2                      4.7            18.562450             73.916619
# 3                      4.3            30.899584             75.809346
# 4                      4.7            26.463504             80.372929
#
#    Delivery_location_latitude  Delivery_location_longitude Time_Orderd  ...
# 0                   30.397968                    78.116106       21:55  ...  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Time_Orderd', 'Time_Order_picked',
#        'Weather_conditions', 'Road_traffic_density', 'Vehicle_condition',
#        'Type_of_order', 'Type_of_vehicle', 'multiple_deliveries', 'Festival',
#        'City', 'Time_taken (min)', 'distance', 'orderdate', 'ordermonth'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0                       int64
# ID                              object
# Delivery_person_ID              object
# Delivery_person_Age            float64
# Delivery_person_Ratings        float64
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Time_Orderd                     object
# Time_Order_picked               object
# Weather_conditions              object
# Road_traffic_density            object
# Vehicle_condition                int64
# Type_of_order                   object
# Type_of_vehicle                 object
# multiple_deliveries            float64
# Festival                        object
# City                            object
# Time_taken (min)                 int64
# distance                       float64
# orderdate                        int64
# ordermonth                       int64
# dtype: object

# %%
df.drop(labels=['Unnamed: 0','ID'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0      DEHRES17DEL01                 36.0                      4.2  \
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            30.327968             78.046106                   30.397968  \
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude Time_Orderd Time_Order_picked
# ...

# %%
## INDEPENDENT AND DEPENDENT FEATURES
X=df.drop(labels=['Time_taken (min)','Delivery_person_ID','Restaurant_latitude','Restaurant_longitude','Delivery_location_latitude','Delivery_location_longitude','orderdate','ordermonth'],axis=1)
y=df[['Time_taken (min)']]

# %%
# Define which columns should be ordinal-encoded and which should be scaled
categorical_cols = X.select_dtypes(include='object').columns
numerical_cols = X.select_dtypes(exclude='object').columns

# %%
# Define the custom ranking for each ordinal variable
Road_traffic_density_categories = ['Low', 'Medium', 'High', 'Jam']
City_categories = ['Semi-Urban', 'Urban', 'Metropolitian']

# %%
numerical_cols
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Vehicle_condition',
#        'multiple_deliveries', 'distance'],
#       dtype='object')

# %%
categorical_cols
# Out:
# Index(['Time_Orderd', 'Time_Order_picked', 'Weather_conditions',
#        'Road_traffic_density', 'Type_of_order', 'Type_of_vehicle', 'Festival',
#        'City'],
#       dtype='object')

# %%
df['Time_taken (min)'].dtypes
# Out:
# dtype('int64')

# %%
pd.value_counts(df['Vehicle_condition'])
# Out:
# Vehicle_condition
# 1    14930
# 2    14927
# 0    14910
# 3      386
# Name: count, dtype: int64

# %%
from sklearn.impute import SimpleImputer ## HAndling Missing Values
from sklearn.preprocessing import StandardScaler # HAndling Feature Scaling
from sklearn.preprocessing import OrdinalEncoder # Ordinal Encoding
## pipelines
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
## Numerical Pipeline
num_pipeline=Pipeline(
    steps=[
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler',StandardScaler())

    ]

)

# Categorigal Pipeline
cat_pipeline = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('scaler', StandardScaler())
])



preprocessor=ColumnTransformer([
('num_pipeline',num_pipeline,numerical_cols),
('cat_pipeline',cat_pipeline,categorical_cols)
])

# %%
oe= OrdinalEncoder(categories=[Road_traffic_density_categories,City_categories])

# %%
# Define the custom ranking for each ordinal variable
Road_traffic_density_categories = ['Low', 'Medium', 'High', 'Jam']
City_categories = ['Semi-Urban', 'Urban', 'Metropolitian']

# %%
oe.fit(X[['Road_traffic_density','City']])
# Out:
# OrdinalEncoder(categories=[['Low', 'Medium', 'High', 'Jam'],
#                            ['Semi-Urban', 'Urban', 'Metropolitian']])

# %%
b=pd.DataFrame(oe.fit_transform(X[['Road_traffic_density','City']]))

# %%
b
# Out:
#        Road_traffic_density  City
# 0                       3.0   2.0
# 1                       2.0   2.0
# 2                       1.0   2.0
# 3                       0.0   2.0
# 4                       3.0   2.0
# ...                     ...   ...
# 45148                   2.0   2.0
# 45149                   3.0   2.0
# 45150                   0.0   2.0
# 45151                   2.0   2.0
# 45152                   1.0   2.0
#
# [45153 rows x 2 columns]

# %%
b.rename(columns={'0': 'Road_traffic_density', '1': 'City'},inplace=True)

# %%
b['Road_traffic_density'] = b[0]
b['City'] = b[1]

# %%
b.drop(labels=[0,1],axis=1,inplace=True)

# %%
pd.concat([df,b],axis=1)
# Out:
#       Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0          DEHRES17DEL01                 36.0                      4.2  \
# 1          KOCRES16DEL01                 21.0                      4.7
# 2         PUNERES13DEL03                 23.0                      4.7
# 3         LUDHRES15DEL02                 34.0                      4.3
# 4          KNPRES14DEL02                 24.0                      4.7
# ...                  ...                  ...                      ...
# 45148      JAPRES04DEL01                 30.0                      4.8
# 45149      AGRRES16DEL01                 21.0                      4.6
# 45150     CHENRES08DEL03                 30.0                      4.9
# 45151    COIMBRES11DEL01                 20.0                      4.7
# 45152   RANCHIRES09DEL02                 23.0                      4.9
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# ...

# %%
df.columns
# Out:
# Index(['Delivery_person_ID', 'Delivery_person_Age', 'Delivery_person_Ratings',
#        'Restaurant_latitude', 'Restaurant_longitude',
#        'Delivery_location_latitude', 'Delivery_location_longitude',
#        'Time_Orderd', 'Time_Order_picked', 'Weather_conditions',
#        'Road_traffic_density', 'Vehicle_condition', 'Type_of_order',
#        'Type_of_vehicle', 'multiple_deliveries', 'Festival', 'City',
#        'Time_taken (min)', 'distance', 'orderdate', 'ordermonth'],
#       dtype='object')

# %%
## Train test split

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=30)

# %%
X_train

# %%
X=pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out())
X_test=pd.DataFrame(preprocessor.transform(X_test),columns=preprocessor.get_feature_names_out())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[236], line 1
# ----> 1 X=pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out())
#       2 X_test=pd.DataFrame(preprocessor.transform(X_test),columns=preprocessor.get_feature_names_out())
#
# File d:\Food Delivery Time Prediction\venv\lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# ...
